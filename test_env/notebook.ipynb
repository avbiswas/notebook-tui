# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [1, 4, 9])
plt.title("demo plot")
# Out:
# image/png output

# %% [markdown]
# # Testing markdown

# %%
print("hi")
# Out:
# hi

# %%
a = 1
b = 2

# %%
a + b

# %%
import time
for i in range(3):
  print(i)
  time.sleep(2)
# Out:
# 0
# 1
# 2
