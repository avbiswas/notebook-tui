# %%
# ntui: label="Highlight" input=fade
# ntui: highlight=1-3 highlight_focus=2
import math
import matplotlib.pyplot as plt
x = 10
print(x ** 2)
# Out:
# 100

# %%
# ntui: label="Preview"
# ntui: preview=@,@o preview_layout=columns
for i in range(1, 4):
    print(f"{i} -> {i**2}")
# Out:
# 1 -> 1
# 2 -> 4
# 3 -> 9

# %%
# ntui: label="Callout"
# ntui: preview=@,@o preview_layout=columns
# ntui: callout="Area of a circle"
r = 5
area = math.pi * r ** 2
print(f"r={r}, area={area:.2f}")
# Out:
# r=5, area=78.54

# %%
# ntui: label="Arrow"
# ntui: arrow="2|math.pi:The constant pi"
d = 10
c = math.pi * d
print(f"C={c:.2f}")
# Out:
# C=31.42

# %%
# ntui: label="Plot" output=preview
x = range(1, 8)
y = [n**2 for n in x]
plt.plot(x, y, 'o-')
plt.title('Squares')
plt.show()
# Out:
# <notebook-cell>:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
# matplotlib figure 1
