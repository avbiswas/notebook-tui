# %%
# ntui: id=parse label="Highlight" highlight=2-3 highlight_focus=3 callout="Only line 3 stays bright"
value = 21
doubled = value * 2
result = {'n': doubled}
result

# %%
# ntui: label="Source Preview" source=preview callout="Source opens in the overlay"
rows = [1, 2, 3]
rows

# %%
# ntui: label="Two-Up" preview=@,@o preview_layout=columns callout="Code and output together"
pairs = [{'a': 1}, {'a': 2}]
pairs

# %%
# ntui: label="By Id" preview=parse,parseo,@o preview_layout=grid callout="Mix named refs with current output"
final = {'done': True}
final
