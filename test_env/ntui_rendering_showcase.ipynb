# %%
# ntui: chapter="Fade" input=fade
note = {
    'kind': 'fade',
    'ok': True
}

note

# %%
# ntui: chapter="Preview" input=present output=preview
rows = [
    {'n': 1, 'tag': 'one'},
    {'n': 2, 'tag': 'two'},
    {'n': 3, 'tag': 'three'},
    {'n': 4, 'tag': 'four'}
]

rows
