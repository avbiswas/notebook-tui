# %% [markdown]
# # ntui Rendering Showcase
#
# Small notebook for fast targeted render tests.

# %%
# ntui: chapter="Grammar" input=present output=preview
# normal comment stays visible

{'demo': 'grammar', 'ok': True}

# %%
# ntui: chapter="Dict" input=fade output=preview
profile = {
    'name': 'Ada',
    'summary': 'Early program notes for the analytical engine.',
    'focus': ['math', 'logic']
}

profile

# %%
# ntui: chapter="List" input=fade output=preview
people = [
    {'name': 'Grace', 'tag': 'compiler'},
    {'name': 'Katherine', 'tag': 'orbit'}
]

people

# %%
# ntui: chapter="Stream" input=present output=preview
import sys
import time

for i in range(6):
    sys.stdout.write(f"tick {i}\n")
    sys.stdout.flush()
    time.sleep(0.05)

# %%
# ntui: chapter="Error" input=present output=preview
def boom():
    raise RuntimeError('show traceback')

boom()

# %%
# ntui: chapter="Image" input=present output=preview
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [1, 3, 2])
plt.title('demo')
plt.show()
